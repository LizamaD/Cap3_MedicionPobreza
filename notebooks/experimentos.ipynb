# %%
# !rm -rf Cap3_MedicionPobreza
# !git clone https://github.com/LizamaD/Cap3_MedicionPobreza.git
# Out:
# Cloning into 'Cap3_MedicionPobreza'...
# remote: Enumerating objects: 231, done.
# remote: Counting objects: 100% (231/231), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 231 (delta 133), reused 183 (delta 85), pack-reused 0 (from 0)
# Receiving objects: 100% (231/231), 4.42 MiB | 11.31 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
# 1. Montar Google Drive para acceder a tus archivos
#from google.colab import drive
#drive.mount('/content/drive')

# 2. Definir la ruta a tu proyecto
#    Asegúrate de que esta ruta sea la correcta para tu estructura de carpetas
#PROJECT_DIR = "/content/drive/MyDrive/Doctorado_DavidLizama/modelos_tesis/Cap3_MedicionPobreza"
# %cd /content/Cap3_MedicionPobreza

# 3. Instalar todas las dependencias desde tu archivo requirements.txt
#    Esto es más limpio y profesional que tener varios !pip install
print("Instalando dependencias desde requirements.txt...")
# !pip install -r "requirements.txt"
# Out:
# /content/Cap3_MedicionPobreza
# Instalando dependencias desde requirements.txt...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 16.4 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf

# Verificamos que TensorFlow esté viendo la GPU
gpu_devices = tf.config.list_physical_devices('GPU')

if gpu_devices:
    print(f"¡Chingón! GPU detectada y lista para la acción: {gpu_devices}")
else:
    print("¡Aguas! No se detectó ninguna GPU. Ve al menú 'Entorno de ejecución' y activa la GPU.")
# Out:
# ¡Chingón! GPU detectada y lista para la acción: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# 4. Ejecutar el script de tuning de hiperparámetros
#    Usamos el comando !python para correr el archivo .py desde el notebook
print("\nIniciando el proceso de tuning con Optuna... Esto puede tardar.")
print("==============================================================")

script_path = f"src/tune_autoencoder.py"
# !python "{script_path}"

print("==============================================================")
print("¡Proceso de tuning finalizado!")
# Out:
# Iniciando el proceso de tuning con Optuna... Esto puede tardar.
# ...
# 2026-03-26 02:01:11.944094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774490471.958668    2347 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774490471.963627    2347 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774490471.975384    2347 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import pandas as pd

# 5. Cargar y mostrar los resultados del estudio de Optuna
results_path = f"/content/drive/MyDrive/Doctorado_DavidLizama/datos_tesis/coneval/2024/Bases de datos/optuna_study_results.csv"
try:
    results_df = pd.read_csv(results_path)
    print("\nResumen de los mejores trials encontrados por Optuna:")
    
    # Ordenamos por el valor de la pérdida (de menor a mayor) y mostramos los 5 mejores
    display(results_df.sort_values(by='value').head(5))
    
except FileNotFoundError:
    print(f"No se encontró el archivo de resultados en '{results_path}'. Asegúrate de que el script de tuning se ejecutó correctamente.")
# Out:
# Resumen de los mejores trials encontrados por Optuna:
#     number     value              datetime_start           datetime_complete  \
# 62      62  2.072912  2026-03-26 03:36:26.715089  2026-03-26 03:38:01.371724
# 34      34  2.112419  2026-03-26 02:47:10.317777  2026-03-26 02:49:02.410906
# 98      98  2.274547  2026-03-26 04:32:45.238699  2026-03-26 04:34:22.130208
# 93      93  2.278760  2026-03-26 04:25:14.149121  2026-03-26 04:26:50.893912
# 85      85  2.345596  2026-03-26 04:12:42.113393  2026-03-26 04:14:19.392880
#
#                   duration  params_bottleneck_dim  params_dropout  params_lr  \
# 62  0 days 00:01:34.656635                     15        0.032113   0.000576
# 34  0 days 00:01:52.093129                     16        0.004366   0.000219
# 98  0 days 00:01:36.891509                     15        0.022986   0.000460
# 93  0 days 00:01:36.744791                     16        0.023715   0.000260
# ...

# %%
print(f"El mejor modelo tiene los parámetros: {results_df.iloc[62,:]}")
# Out:
# El mejor modelo tiene los parámetros: number                                           62
# value                                      2.072912
# datetime_start           2026-03-26 03:36:26.715089
# datetime_complete        2026-03-26 03:38:01.371724
# duration                     0 days 00:01:34.656635
# params_bottleneck_dim                            15
# params_dropout                             0.032113
# params_lr                                  0.000576
# params_n_layers                                   3
# params_units_layer_0                            432
# params_units_layer_1                            387
# params_units_layer_2                            362
# params_units_layer_3                            107
# params_units_layer_4                             66
# state                                      COMPLETE
# Name: 62, dtype: object
